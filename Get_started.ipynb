# %% [markdown]
# # Health Data Analytics training 2024
#
# ## Introduction to Machine learning
#
# Individual Task Manual workflow

# %% [markdown]
# ### STEP 1: Organizing the data

# %% [markdown]
# #### 1A: Import modules

# %%
import sys
# !{sys.executable} -m pip install numpy pandas matplotlib scikit-learn seaborn plotnine imblearn optuna| grep -v 'already satisfied'

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import csv
import os

#Set seed for reproducibility
import random
random.seed(5059)
# Out:
# DEPRECATION: Loading egg at /Users/annabelitaeli/anaconda3/lib/python3.11/site-packages/cvxpy-1.5.0-py3.11-macosx-11.1-arm64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330

# %% [markdown]
# #### 1B: Load the data

# %%
# Read the dataset from the file

# Obtain the current working directory of the file: ensure notebook and dataset are within the same folder
cwd = os.getcwd()
#print ('Current working Directory:', cwd)

# Obtain the directory of the training dataset within the folder
data_dir = os.path.join(cwd, 'CLD_lab_data.csv')
#print ('Directory for the train dataset:', train_dir)

# Importing the training dataset
CLD_lab_data = pd.read_csv(data_dir)

# Checking the number of observations and features
CLD_lab_data.shape
# Out:
# (7905, 20)

# %%
# Visualize the maximum number of columns that can be displayed.
pd.set_option('display.max_columns', None)
display(CLD_lab_data)
# Out:
#         id  N_Days             Drug    Age Sex Ascites Hepatomegaly Spiders  \
# 0        0     999  D-penicillamine  21532   M       N            N       N
# 1        1    2574          Placebo  19237   F       N            N       N
# 2        2    3428          Placebo  13727   F       N            Y       Y
# 3        3    2576          Placebo  18460   F       N            N       N
# 4        4     788          Placebo  16658   F       N            Y       N
# ...    ...     ...              ...    ...  ..     ...          ...     ...
# 7900  7900    1166  D-penicillamine  16839   F       N            N       N
# 7901  7901    1492          Placebo  17031   F       N            Y       N
# 7902  7902    1576  D-penicillamine  25873   F       N            N       Y
# 7903  7903    3584  D-penicillamine  22960   M       N            Y       N
# 7904  7904    1978  D-penicillamine  19237   F       N            N       N
#
# ...

# %% [markdown]
# #### 1C: Create copy of dataset for data exploration,

# %%
# The function (Deep=true) makes the new dataset independent of the original dataset, 
# This is important to ensure that modifications to the copied DataFrame do not affect the original DataFrame

lab_data = CLD_lab_data.copy(deep=True)

# %%
# Moving forward, we will use the copy dataset
